# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
import numpy as np

#使用pandas模組讀取excel資料;u表示unicode編碼;sheetname=1表示第二張工作表，0表示第一張;skiprows=3表示前四行略過
df = pd.read_excel(u'K:\\20171027資料前處理\\降水分級20171108\\13-全年_分區_降水分級_不含條目之西曆月份起迄-9999\\華北次分區\\North_China_SubDistrict_avg_std.xlsx',sheetname=0)
#顯示前5行資料
df.head(2)
# Out:
#    Year  avg_B4    std_B4    avg_B5    std_B5  avg_B6  std_B6  avg_B7  std_B7
# 0  1644    -0.5  0.707107 -0.181818  1.296015   -0.75     1.5     1.0     0.0
# 1  1645     0.0  0.000000  0.111111  1.450715   -0.75     1.5     0.0     0.0

# %%
# %matplotlib inline

# %%
YR = df.iloc[:, 0]
B4avg = df.iloc[:, 1]
B4std = df.iloc[:, 2]
B5avg = df.iloc[:, 3]
B5std = df.iloc[:, 4]
B6avg = df.iloc[:, 5]
B6std = df.iloc[:, 6]
B7avg = df.iloc[:, 7]
B7std = df.iloc[:, 8]

# %%
Fig_ts = plt.figure(figsize=(30,12))
plt.plot(YR, B4avg, c="blue")
#plt.errorbar(YR, B4avg, B4std, linestyle='None', marker='o')
plt.plot(YR, B5avg, c="black")
plt.tick_params(axis='x', which='major', labelsize=20)
plt.tick_params(axis='y', which='major', labelsize=20)
plt.legend(fontsize=20)

# %%
B5c=[]
for i in range(len(YR)):
    B5c.append(B5avg[i]+5)
    
B5c
# Out:
# [4.8181818181818183,
#  5.1111111111111107,
#  4.8666666666666663,
#  5.4375,
#  5.5,
#  5.3529411764705879,
#  5.0384615384615383,
#  5.6363636363636367,
#  5.416666666666667,
#  5.9767441860465116,
#  5.9215686274509807,
#  4.583333333333333,
#  5.0,
#  5.2380952380952381,
#  5.5625,
#  5.6923076923076925,
#  4.3600000000000003,
#  4.4117647058823533,
#  5.166666666666667,
#  4.416666666666667,
#  4.0,
#  4.25,
#  5.4615384615384617,
#  4.5185185185185182,
#  5.4693877551020407,
#  5.7727272727272725,
#  4.2195121951219514,
#  4.7179487179487181,
#  5.21875,
#  4.7037037037037042,
#  4.0357142857142856,
#  4.9090909090909092,
#  4.8888888888888893,
#  5.2222222222222223,
#  4.083333333333333,
#  4.0483870967741939,
#  4.125,
#  3.8888888888888888,
#  4.8947368421052628,
#  4.4736842105263159,
#  4.8888888888888893,
#  5.4482758620689653,
#  3.9375,
#  4.0526315789473681,
#  4.2105263157894735,
#  4.064516129032258,
#  3.9230769230769234,
#  4.2571428571428571,
# ...

# %%
Fig_ts = plt.figure(figsize=(30,12))
plt.plot(YR, B4avg, c="blue")
#plt.errorbar(YR, B4avg, B4std, linestyle='None', marker='o')
plt.plot(YR, B5c, c="black",label='avg_B5')
plt.tick_params(axis='x', which='major', labelsize=20)
plt.tick_params(axis='y', which='major', labelsize=20)
plt.legend(loc='lower right',fontsize=20)
plt.grid(True)
ax = plt.gca()
ax.spines["right"].set_color('none')
ax.spines["left"].set_color('none')
ax.spines["top"].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines["bottom"].set_position(('data',2.5))
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.figure(figsize=(30,12))
ax1 = plt.subplot2grid((4,3),(0,0),colspan=3)
ax1.plot(YR, B4avg, c="blue")
ax1.legend(fontsize=20,loc='lower right')
#ax1.grid(True)
plt.title("North China Sub-Distict B4-B7, Annual Precipitation Index, 1644-1911", fontsize=30)
#help(ax1.ticklabel_format)
ax1.tick_params(axis='x', which='major', labelsize=20)
ax1.tick_params(axis='y', which='major', labelsize=20)
ax1.spines["right"].set_color('none')
ax1.spines["left"].set_color('none')
ax1.spines["top"].set_color('none')
ax1.spines["bottom"].set_color('none')
plt.xticks([])

ax2 = plt.subplot2grid((4,3),(1,0),colspan=3)
ax2.plot(YR, B5avg, c="black")
ax2.legend(fontsize=20,loc='lower right')
ax2.tick_params(axis='x', which='major', labelsize=20)
ax2.tick_params(axis='y', which='major', labelsize=20)
ax2.spines["right"].set_color('none')
ax2.spines["left"].set_color('none')
ax2.spines["top"].set_color('none')
ax2.spines["bottom"].set_color('none')
plt.ylim(-2,2)
plt.xticks([])

ax3 = plt.subplot2grid((4,3),(2,0),colspan=3)
ax3.plot(YR, B6avg, c="green")
ax3.legend(fontsize=20,loc='lower right')
ax3.tick_params(axis='x', which='major', labelsize=20)
ax3.tick_params(axis='y', which='major', labelsize=20)
ax3.spines["right"].set_color('none')
ax3.spines["left"].set_color('none')
ax3.spines["top"].set_color('none')
ax3.spines["bottom"].set_color('none')
plt.xticks([])

ax4 = plt.subplot2grid((4,3),(3,0),colspan=3)
ax4.plot(YR, B7avg, c="red")
ax4.legend(fontsize=20,loc='lower right')
ax4.tick_params(axis='x', which='major', labelsize=20)
ax4.tick_params(axis='y', which='major', labelsize=20)
ax4.spines["right"].set_color('none')
ax4.spines["left"].set_color('none')
ax4.spines["top"].set_color('none')
plt.savefig(u'K:\\20171027資料前處理\\降水分級20171108\\13-全年_分區_降水分級_不含條目之西曆月份起迄-9999\\華北次分區\\N_B4_B7_API.jpg')

# %%
plt.figure(figsize=(30,12))
ax1 = plt.subplot2grid((4,3),(0,0),colspan=3)
ax1.plot(YR, B4avg, c="blue")
ax1.legend(fontsize=20,loc='lower right')
B4rm10 =  B4avg.rolling(10, min_periods=10).mean()
ax1.plot(YR, B4rm10, c="darkblue")
#ax1.grid(True)
plt.title("North China Sub-Distict B4-B7, Annual Precipitation Index, 1644-1911", fontsize=30)
#help(ax1.ticklabel_format)
ax1.tick_params(axis='x', which='major', labelsize=20)
ax1.tick_params(axis='y', which='major', labelsize=20)
ax1.spines["right"].set_color('none')
ax1.spines["left"].set_color('none')
ax1.spines["top"].set_color('none')
ax1.spines["bottom"].set_color('none')
plt.xticks([])

ax2 = plt.subplot2grid((4,3),(1,0),colspan=3)
ax2.plot(YR, B5avg, c="black")
ax2.legend(fontsize=20,loc='lower right')
B5rm10 =  B5avg.rolling(10, min_periods=10).mean()
ax2.plot(YR, B5rm10, c="black")
ax2.tick_params(axis='x', which='major', labelsize=20)
ax2.tick_params(axis='y', which='major', labelsize=20)
ax2.spines["right"].set_color('none')
ax2.spines["left"].set_color('none')
ax2.spines["top"].set_color('none')
ax2.spines["bottom"].set_color('none')
plt.ylim(-2,2)
plt.xticks([])

ax3 = plt.subplot2grid((4,3),(2,0),colspan=3)
ax3.plot(YR, B6avg, c="green")
ax3.legend(fontsize=20,loc='lower right')
B6rm10 =  B6avg.rolling(10, min_periods=10).mean()
ax3.plot(YR, B6rm10, c="darkgreen")
ax3.tick_params(axis='x', which='major', labelsize=20)
ax3.tick_params(axis='y', which='major', labelsize=20)
ax3.spines["right"].set_color('none')
ax3.spines["left"].set_color('none')
ax3.spines["top"].set_color('none')
ax3.spines["bottom"].set_color('none')
plt.xticks([])

ax4 = plt.subplot2grid((4,3),(3,0),colspan=3)
ax4.plot(YR, B7avg, c="red")
ax4.legend(fontsize=20,loc='lower right')
B7rm10 =  B7avg.rolling(10, min_periods=10).mean()
ax4.plot(YR, B7rm10, c="maroon")
ax4.tick_params(axis='x', which='major', labelsize=20)
ax4.tick_params(axis='y', which='major', labelsize=20)
ax4.spines["right"].set_color('none')
ax4.spines["left"].set_color('none')
ax4.spines["top"].set_color('none')
plt.savefig(u'K:\\20171027資料前處理\\降水分級20171108\\13-全年_分區_降水分級_不含條目之西曆月份起迄-9999\\華北次分區\\N_B4_B7_API_rm10.jpg')

# %%
plt.figure(figsize=(30,12))
plt.title("North China Sub-Distict B4-B7, Annual Precipitation Index, 10 Years Running Mean, 1644-1911", fontsize=30)
plt.plot(YR, B4rm10, c="darkblue", label='B4')
plt.plot(YR, B5rm10, c="black", label='B5')
plt.plot(YR, B6rm10, c="darkgreen", label='B6')
plt.plot(YR, B7rm10, c="maroon", label='B7')
plt.tick_params(axis='x', which='major', labelsize=20)
plt.tick_params(axis='y', which='major', labelsize=20)
plt.ylim(-2,2)
plt.legend(fontsize=30)
plt.savefig(u'K:\\20171027資料前處理\\降水分級20171108\\13-全年_分區_降水分級_不含條目之西曆月份起迄-9999\\華北次分區\\N_B4_B7_API_combine_rm10.jpg')

# %%
plt.figure(figsize=(30,12))
ax1 = plt.subplot2grid((4,3),(0,0),colspan=3)
ax1.plot(YR, B4avg, c="blue", label='B4')
ax1.legend(fontsize=20,loc='lower right')
B4rm30 =  B4avg.rolling(30, min_periods=30).mean()
ax1.plot(YR, B4rm30, c="darkblue")
#ax1.grid(True)
plt.title("North China Sub-Distict B4-B7, Annual Precipitation Index, 1644-1911", fontsize=30)
#help(ax1.ticklabel_format)
ax1.tick_params(axis='x', which='major', labelsize=20)
ax1.tick_params(axis='y', which='major', labelsize=20)
ax1.spines["right"].set_color('none')
ax1.spines["left"].set_color('none')
ax1.spines["top"].set_color('none')
ax1.spines["bottom"].set_color('none')
plt.xticks([])

ax2 = plt.subplot2grid((4,3),(1,0),colspan=3)
ax2.plot(YR, B5avg, c="black", label='B5')
ax2.legend(fontsize=20,loc='lower right')
B5rm30 =  B5avg.rolling(30, min_periods=30).mean()
ax2.plot(YR, B5rm30, c="black")
ax2.tick_params(axis='x', which='major', labelsize=20)
ax2.tick_params(axis='y', which='major', labelsize=20)
ax2.spines["right"].set_color('none')
ax2.spines["left"].set_color('none')
ax2.spines["top"].set_color('none')
ax2.spines["bottom"].set_color('none')
plt.ylim(-2,2)
plt.xticks([])

ax3 = plt.subplot2grid((4,3),(2,0),colspan=3)
ax3.plot(YR, B6avg, c="green", label='B6')
ax3.legend(fontsize=20,loc='lower right')
B6rm30 =  B6avg.rolling(30, min_periods=30).mean()
ax3.plot(YR, B6rm30, c="darkgreen")
ax3.tick_params(axis='x', which='major', labelsize=20)
ax3.tick_params(axis='y', which='major', labelsize=20)
ax3.spines["right"].set_color('none')
ax3.spines["left"].set_color('none')
ax3.spines["top"].set_color('none')
ax3.spines["bottom"].set_color('none')
plt.xticks([])

ax4 = plt.subplot2grid((4,3),(3,0),colspan=3)
ax4.plot(YR, B7avg, c="red", label='B7')
ax4.legend(fontsize=20,loc='lower right')
B7rm30 =  B7avg.rolling(30, min_periods=30).mean()
ax4.plot(YR, B7rm30, c="maroon")
ax4.tick_params(axis='x', which='major', labelsize=20)
ax4.tick_params(axis='y', which='major', labelsize=20)
ax4.spines["right"].set_color('none')
ax4.spines["left"].set_color('none')
ax4.spines["top"].set_color('none')
plt.savefig(u'K:\\20171027資料前處理\\降水分級20171108\\13-全年_分區_降水分級_不含條目之西曆月份起迄-9999\\華北次分區\\N_B4_B7_API_rm30.jpg')

# %%
plt.figure(figsize=(30,12))
plt.title("North China Sub-Distict B4-B7, Annual Precipitation Index, 30 Years Running Mean, 1644-1911", fontsize=30)
plt.plot(YR, B4rm30, c="darkblue", label='B4')
plt.plot(YR, B5rm30, c="black", label='B5')
plt.plot(YR, B6rm30, c="darkgreen", label='B6')
plt.plot(YR, B7rm30, c="maroon", label='B7')
plt.tick_params(axis='x', which='major', labelsize=20)
plt.tick_params(axis='y', which='major', labelsize=20)
plt.ylim(-1,1)
plt.legend(fontsize=30, loc='lower right')
plt.savefig(u'K:\\20171027資料前處理\\降水分級20171108\\13-全年_分區_降水分級_不含條目之西曆月份起迄-9999\\華北次分區\\N_B4_B7_API_combine_rm30.jpg')

# %%
plt.figure(figsize=(30,20))
ax1 = plt.subplot2grid((4,3),(0,0),colspan=3)
ax1.plot(YR, B4avg, c="blue", label="B4")
ax1.legend(fontsize=20,loc='lower right')
ax1.errorbar(YR, B4avg, B4std, linestyle='None', marker='o', c="blue")
#B4rm10 =  B4avg.rolling(10, min_periods=10).mean()
#ax1.plot(YR, B4rm10, c="darkblue")
#ax1.grid(True)
plt.title("North China Sub-Distict B4-B7, Annual Precipitation Index, 1644-1911", fontsize=30)
#help(ax1.ticklabel_format)
ax1.tick_params(axis='x', which='major', labelsize=20)
ax1.tick_params(axis='y', which='major', labelsize=20)
ax1.spines["right"].set_color('none')
ax1.spines["left"].set_color('none')
ax1.spines["top"].set_color('none')
ax1.spines["bottom"].set_color('none')
plt.xticks([])

ax2 = plt.subplot2grid((4,3),(1,0),colspan=3)
ax2.plot(YR, B5avg, c="black", label="B5")
ax2.legend(fontsize=20,loc='lower right')
ax2.errorbar(YR, B5avg, B5std, linestyle='None', marker='o', c="black")
#B5rm10 =  B5avg.rolling(10, min_periods=10).mean()
#ax2.plot(YR, B5rm10, c="gray")
ax2.tick_params(axis='x', which='major', labelsize=20)
ax2.tick_params(axis='y', which='major', labelsize=20)
ax2.spines["right"].set_color('none')
ax2.spines["left"].set_color('none')
ax2.spines["top"].set_color('none')
ax2.spines["bottom"].set_color('none')
#plt.ylim(-2,2)
plt.xticks([])

ax3 = plt.subplot2grid((4,3),(2,0),colspan=3)
ax3.plot(YR, B6avg, c="green", label="B6")
ax3.legend(fontsize=20,loc='lower right')
ax3.errorbar(YR, B6avg, B6std, linestyle='None', marker='o', c="green")
#B6rm10 =  B6avg.rolling(10, min_periods=10).mean()
#ax3.plot(YR, B6rm10, c="darkgreen")
ax3.tick_params(axis='x', which='major', labelsize=20)
ax3.tick_params(axis='y', which='major', labelsize=20)
ax3.spines["right"].set_color('none')
ax3.spines["left"].set_color('none')
ax3.spines["top"].set_color('none')
ax3.spines["bottom"].set_color('none')
#plt.ylim(-2,2)
plt.xticks([])

ax4 = plt.subplot2grid((4,3),(3,0),colspan=3)
ax4.plot(YR, B7avg, c="red", label="B7")
ax4.legend(fontsize=20,loc='lower right')
ax4.errorbar(YR, B7avg, B7std, linestyle='None', marker='o', c="red")
#B7rm10 =  B7avg.rolling(10, min_periods=10).mean()
#ax4.plot(YR, B7rm10, c="maroon")
ax4.tick_params(axis='x', which='major', labelsize=20)
ax4.tick_params(axis='y', which='major', labelsize=20)
ax4.spines["right"].set_color('none')
ax4.spines["left"].set_color('none')
ax4.spines["top"].set_color('none')
plt.savefig(u'K:\\20171027資料前處理\\降水分級20171108\\13-全年_分區_降水分級_不含條目之西曆月份起迄-9999\\華北次分區\\N_B4_B7_API_std.jpg')
